# %%
pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
# import tweepy
import tweepy as tw

# your Twitter API key and API secret
my_api_key = "QSH8FDRc5YqW3bVpaytpQICuA"
my_api_secret = "FB4KE6Kf1LNutm1oEHjm72aGFR9qvO5bgMdgVrMXrqurxoX5xj"

# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_query = "#etherum -filter:retweets"

# %%
# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2022-09-01", until="2022-10-08").items(300)

# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Total Tweets fetched: 251

# %%
import pandas as pd

# intialize the dataframe
tweets_df = pd.DataFrame()

# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)

# show the dataframe
tweets_df.head()
# Out:
#                               user_name user_location  \
# 0                         Bots in Space
# 1                          Crypto Pylon
# 2                              eggzesty
# 3                                 Watty
# 4  Digital Garage Volkswagen - PROMOTER
#
#                                     user_description  user_verified  \
# 0  Unique 3D Bot from the popular Bots in Space N...          False
# 1     We Are Independent Global Crypto News Website.          False
# 2        The harder you fall, the higher you bounce.          False
# 3                                 Sendiri lebih baik          False
# 4  Trade Profissinal - FX \nNFT's Broker and Anal...          False
#
#                  date                                               text  \
# 0 2022-10-07 23:34:38  Time Keepers.\n\nSite: https://t.co/an9m9dZegs...
# 1 2022-10-07 23:00:44  Payment of 141,000 BTC to previousMt Gox consu...
# 2 2022-10-07 22:53:30  100k $ in 2021 V Now👇\n#Bitcoin : 29000$ \n#Et...
# 3 2022-10-07 22:42:19  @WombexFlnance I wish the owners &amp; staff a...
# 4 2022-10-07 22:14:52  GN 🌑 Check out this item on OpenSea !!\n\nhttp...
#
#                                             hashtags               source
# 0  [botsinspace, NFTartists, nft, NFTCommunity, E...      Twitter Web App
# 1                  [Bitcoin, BTC, Crypto, Metaverse]          cryptopylon
# 2           [Bitcoin, Etherum, XRP, BNB, Doge, AVAX]  Twitter for Android
# 3                                               None      Twitter Web App
# 4                     [NFTCommunity, NFTcollections]      Twitter Web App

# %%
tweets_df.tail()
# Out:
#         user_name  user_location  \
# 246  Crypto Billu   🇮🇳💎Join us »
# 247     CryptoDad
# 248     Tokenview     Blockchain
# 249          Masa  San Francisco
# 250  TsukuyomiXBT      Atlantis
#
#                                       user_description  user_verified  \
# 246  All about #Crypto 🚀░ Free Signals, News, T.A+F...          False
# 247  ❤💛 #web3social @xx_network @Aleph__Zero @DeroP...          False
# 248  Multi-Crypto Blockchain Explorer&Data Platform...          False
# 249  🌽 Masa Soulbound Identity aims to power mainst...          False
# 250  derivatives trader - currently documenting 1k ...          False
#
#                    date                                               text  \
# 246 2022-10-07 06:28:31  #Altcoins are being released into the market a...
# 247 2022-10-07 06:24:33  Claim free crypto every 60 minutes. —&amp;gt; ...
# 248 2022-10-07 06:24:18  BNB chain hackers have transferred $89.5 milli...
# 249 2022-10-07 06:18:31  “Your privacy is safu”…this is why we need pri...
# 250 2022-10-07 06:16:07  Can you bulls give me a chance to buy eth near...
#
#                                               hashtags              source
# 246                                         [Altcoins]  Twitter for iPhone
# 247  [SHIB, Etherum, CryptoNews, cryptocurrecy, Lit...     Twitter Web App
# 248                                               None     Twitter Web App
# 249                                               None  Twitter for iPhone
# 250                                          [Etherum]  Twitter for iPhone
